# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 709

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | constitucion
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | codrington
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | cockburn harbour
# City not found. Skipping...
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | isangel
# Processing Record 11 of Set 1 | san nicolas guadalupe
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | lahij
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | zhangye
# Processing Record 17 of Set 1 | ardon
# Processing Record 18 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 1 | pangody
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | kruisfontein
# Processing Record 22 of Set 1 | banda aceh
# Processing Record 23 of Set 1 | mount isa
# Processing Record 24 of Set 1 | saint-philippe
# Processing Record 25 of Set 1 | sept-iles
# Processing Record 26 of Set 1 | coihaique
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | gat
# Processing Record 32 of Set 1 | owando
# Processing Record 33 of Set 1 | salumbar
# Processing Record 34 of Set 1 | nadym
# Processing Record 35 of Set 1 | klaksvik
# Processing Record 36 of Set 1 | norman wells
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | kahului
# Processing Record 40 of Set 1 | marystown
# Processing Record 41 of Set 1 | villanueva de la serena
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | grand gaube
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | pandan
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 1 of Set 2 | narsaq
# Processing Record 2 of Set 2 | port hardy
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | jishou
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | east london
# Processing Record 7 of Set 2 | naze
# Processing Record 8 of Set 2 | ornskoldsvik
# Processing Record 9 of Set 2 | isagarh
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 2 | faya
# Processing Record 14 of Set 2 | guaymas
# Processing Record 15 of Set 2 | sao filipe
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | cabo san lucas
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | bairiki
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | san juan bautista
# Processing Record 22 of Set 2 | roma
# Processing Record 23 of Set 2 | komsomolskiy
# Processing Record 24 of Set 2 | paragominas
# Processing Record 25 of Set 2 | mecca
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | hazorasp
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | severo-kurilsk
# Processing Record 32 of Set 2 | iquique
# Processing Record 33 of Set 2 | luderitz
# Processing Record 34 of Set 2 | havre-saint-pierre
# Processing Record 35 of Set 2 | iqaluit
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | nouadhibou
# Processing Record 38 of Set 2 | sisimiut
# Processing Record 39 of Set 2 | hammerfest
# Processing Record 40 of Set 2 | ambilobe
# Processing Record 41 of Set 2 | doha
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | saint george
# Processing Record 44 of Set 2 | ucluelet
# Processing Record 45 of Set 2 | lata
# Processing Record 46 of Set 2 | pleasanton
# Processing Record 47 of Set 2 | carmo
# Processing Record 48 of Set 2 | catamarca
# Processing Record 49 of Set 2 | belyy yar
# Processing Record 50 of Set 2 | omsukchan
# Processing Record 1 of Set 3 | caravelas
# Processing Record 2 of Set 3 | katsiveli
# City not found. Skipping...
# Processing Record 3 of Set 3 | rawson
# Processing Record 4 of Set 3 | benguela
# Processing Record 5 of Set 3 | bluff
# Processing Record 6 of Set 3 | noumea
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | dikson
# Processing Record 9 of Set 3 | cintalapa
# Processing Record 10 of Set 3 | pacific grove
# Processing Record 11 of Set 3 | lagoa
# Processing Record 12 of Set 3 | hovd
# Processing Record 13 of Set 3 | marsaxlokk
# Processing Record 14 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 3 | gweta
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | mizdah
# Processing Record 18 of Set 3 | torbay
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | broken hill
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | upernavik
# Processing Record 23 of Set 3 | andros
# Processing Record 24 of Set 3 | kudahuvadhoo
# Processing Record 25 of Set 3 | campina verde
# Processing Record 26 of Set 3 | beidao
# Processing Record 27 of Set 3 | chuy
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | georgetown
# Processing Record 32 of Set 3 | marawi
# Processing Record 33 of Set 3 | takob
# City not found. Skipping...
# Processing Record 34 of Set 3 | bilma
# Processing Record 35 of Set 3 | danville
# Processing Record 36 of Set 3 | san patricio
# Processing Record 37 of Set 3 | richards bay
# Processing Record 38 of Set 3 | innisfail
# Processing Record 39 of Set 3 | nishihara
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | puerto ayora
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | bubaque
# Processing Record 44 of Set 3 | kavaratti
# Processing Record 45 of Set 3 | manta
# Processing Record 46 of Set 3 | aksarayskiy
# Processing Record 47 of Set 3 | warrnambool
# Processing Record 48 of Set 3 | college
# Processing Record 49 of Set 3 | harper
# Processing Record 50 of Set 3 | namibe
# Processing Record 1 of Set 4 | tura
# Processing Record 2 of Set 4 | george
# Processing Record 3 of Set 4 | najran
# Processing Record 4 of Set 4 | moose factory
# Processing Record 5 of Set 4 | yumen
# Processing Record 6 of Set 4 | qaanaaq
# Processing Record 7 of Set 4 | tucson
# Processing Record 8 of Set 4 | la libertad
# Processing Record 9 of Set 4 | asyut
# Processing Record 10 of Set 4 | urdoma
# Processing Record 11 of Set 4 | sao joao da barra
# Processing Record 12 of Set 4 | fenyi
# Processing Record 13 of Set 4 | gamba
# Processing Record 14 of Set 4 | bandar-e anzali
# Processing Record 15 of Set 4 | souillac
# Processing Record 16 of Set 4 | ayan
# Processing Record 17 of Set 4 | ponta delgada
# Processing Record 18 of Set 4 | bengkulu
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | alofi
# Processing Record 21 of Set 4 | oranjemund
# Processing Record 22 of Set 4 | abu dhabi
# Processing Record 23 of Set 4 | eureka
# Processing Record 24 of Set 4 | gravatai
# Processing Record 25 of Set 4 | venice
# Processing Record 26 of Set 4 | cortez
# Processing Record 27 of Set 4 | yakeshi
# Processing Record 28 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 4 | ossora
# Processing Record 30 of Set 4 | ponta do sol
# Processing Record 31 of Set 4 | mayumba
# Processing Record 32 of Set 4 | mwene-ditu
# Processing Record 33 of Set 4 | bud
# Processing Record 34 of Set 4 | longyearbyen
# Processing Record 35 of Set 4 | alice springs
# Processing Record 36 of Set 4 | serebryanyy bor
# Processing Record 37 of Set 4 | tromso
# Processing Record 38 of Set 4 | general teran
# Processing Record 39 of Set 4 | chernyshevskiy
# Processing Record 40 of Set 4 | las cruces
# Processing Record 41 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 4 | sawakin
# Processing Record 43 of Set 4 | baiyin
# Processing Record 44 of Set 4 | tasiilaq
# Processing Record 45 of Set 4 | arraial do cabo
# Processing Record 46 of Set 4 | enugu
# Processing Record 47 of Set 4 | hamilton
# Processing Record 48 of Set 4 | mujiayingzi
# Processing Record 49 of Set 4 | comodoro rivadavia
# Processing Record 50 of Set 4 | nokha
# Processing Record 1 of Set 5 | wanning
# Processing Record 2 of Set 5 | cherskiy
# Processing Record 3 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 5 | zhangjiakou
# Processing Record 5 of Set 5 | katobu
# Processing Record 6 of Set 5 | bredasdorp
# Processing Record 7 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 5 | gorin
# Processing Record 9 of Set 5 | jumla
# Processing Record 10 of Set 5 | san cristobal
# Processing Record 11 of Set 5 | walvis bay
# Processing Record 12 of Set 5 | lompoc
# Processing Record 13 of Set 5 | okhotsk
# Processing Record 14 of Set 5 | leningradskiy
# Processing Record 15 of Set 5 | maltahohe
# Processing Record 16 of Set 5 | kindia
# Processing Record 17 of Set 5 | saint-augustin
# Processing Record 18 of Set 5 | borovo
# Processing Record 19 of Set 5 | nome
# Processing Record 20 of Set 5 | olga
# Processing Record 21 of Set 5 | pemba
# Processing Record 22 of Set 5 | butaritari
# Processing Record 23 of Set 5 | tanout
# Processing Record 24 of Set 5 | tual
# Processing Record 25 of Set 5 | abu kamal
# Processing Record 26 of Set 5 | kiunga
# Processing Record 27 of Set 5 | deputatskiy
# Processing Record 28 of Set 5 | miandrivazo
# Processing Record 29 of Set 5 | aswan
# Processing Record 30 of Set 5 | margate
# Processing Record 31 of Set 5 | geraldton
# Processing Record 32 of Set 5 | shache
# Processing Record 33 of Set 5 | gavrilovka vtoraya
# Processing Record 34 of Set 5 | altamira
# Processing Record 35 of Set 5 | rocha
# Processing Record 36 of Set 5 | mbini
# Processing Record 37 of Set 5 | cancun
# Processing Record 38 of Set 5 | salalah
# Processing Record 39 of Set 5 | katsuura
# Processing Record 40 of Set 5 | mogocha
# Processing Record 41 of Set 5 | tral
# Processing Record 42 of Set 5 | mount gambier
# Processing Record 43 of Set 5 | sarangani
# Processing Record 44 of Set 5 | qasigiannguit
# Processing Record 45 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 5 | tuatapere
# Processing Record 47 of Set 5 | nuuk
# Processing Record 48 of Set 5 | parchim
# Processing Record 49 of Set 5 | madingou
# Processing Record 50 of Set 5 | jibuti
# Processing Record 1 of Set 6 | cidreira
# Processing Record 2 of Set 6 | feicheng
# Processing Record 3 of Set 6 | loikaw
# Processing Record 4 of Set 6 | haapu
# City not found. Skipping...
# Processing Record 5 of Set 6 | homer
# Processing Record 6 of Set 6 | asau
# Processing Record 7 of Set 6 | voyskovitsy
# Processing Record 8 of Set 6 | ostrovnoy
# Processing Record 9 of Set 6 | nador
# Processing Record 10 of Set 6 | podgornoye
# Processing Record 11 of Set 6 | airai
# Processing Record 12 of Set 6 | mount pleasant
# Processing Record 13 of Set 6 | dicabisagan
# Processing Record 14 of Set 6 | ixtapa
# Processing Record 15 of Set 6 | yenagoa
# Processing Record 16 of Set 6 | acapulco
# Processing Record 17 of Set 6 | gombong
# Processing Record 18 of Set 6 | ancud
# Processing Record 19 of Set 6 | meulaboh
# Processing Record 20 of Set 6 | tilichiki
# Processing Record 21 of Set 6 | kamenka
# Processing Record 22 of Set 6 | talnakh
# Processing Record 23 of Set 6 | buraydah
# Processing Record 24 of Set 6 | paamiut
# Processing Record 25 of Set 6 | hearst
# Processing Record 26 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 6 | surt
# Processing Record 28 of Set 6 | flinders
# Processing Record 29 of Set 6 | pinega
# Processing Record 30 of Set 6 | opuwo
# Processing Record 31 of Set 6 | touros
# Processing Record 32 of Set 6 | anshun
# Processing Record 33 of Set 6 | marion
# Processing Record 34 of Set 6 | sorland
# Processing Record 35 of Set 6 | shimoda
# Processing Record 36 of Set 6 | conceicao do araguaia
# Processing Record 37 of Set 6 | ardrishaig
# Processing Record 38 of Set 6 | kaharlyk
# Processing Record 39 of Set 6 | ilulissat
# Processing Record 40 of Set 6 | galle
# Processing Record 41 of Set 6 | westport
# Processing Record 42 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 6 | uhlove
# Processing Record 44 of Set 6 | imeni poliny osipenko
# Processing Record 45 of Set 6 | victoria
# Processing Record 46 of Set 6 | halifax
# Processing Record 47 of Set 6 | saldanha
# Processing Record 48 of Set 6 | sur
# Processing Record 49 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 6 | hasaki
# Processing Record 1 of Set 7 | palora
# Processing Record 2 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 3 of Set 7 | sitka
# Processing Record 4 of Set 7 | hami
# Processing Record 5 of Set 7 | severobaykalsk
# Processing Record 6 of Set 7 | mahebourg
# Processing Record 7 of Set 7 | sretensk
# Processing Record 8 of Set 7 | clyde river
# Processing Record 9 of Set 7 | smithers
# Processing Record 10 of Set 7 | san fernando
# Processing Record 11 of Set 7 | caceres
# Processing Record 12 of Set 7 | rafsanjan
# Processing Record 13 of Set 7 | dunedin
# Processing Record 14 of Set 7 | westerland
# Processing Record 15 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 7 | esil
# Processing Record 17 of Set 7 | kiama
# Processing Record 18 of Set 7 | niteroi
# Processing Record 19 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 7 | urgut
# Processing Record 21 of Set 7 | salinas
# Processing Record 22 of Set 7 | juneau
# Processing Record 23 of Set 7 | coquimbo
# Processing Record 24 of Set 7 | conceicao da barra
# Processing Record 25 of Set 7 | monroe
# Processing Record 26 of Set 7 | dwarka
# Processing Record 27 of Set 7 | daru
# Processing Record 28 of Set 7 | starosubkhangulovo
# Processing Record 29 of Set 7 | atlantic city
# Processing Record 30 of Set 7 | abeche
# Processing Record 31 of Set 7 | fairbanks
# Processing Record 32 of Set 7 | dingle
# Processing Record 33 of Set 7 | tokmak
# Processing Record 34 of Set 7 | puqi
# Processing Record 35 of Set 7 | praskoveya
# Processing Record 36 of Set 7 | ignatovka
# Processing Record 37 of Set 7 | tarakan
# Processing Record 38 of Set 7 | cayenne
# Processing Record 39 of Set 7 | kosh-agach
# Processing Record 40 of Set 7 | skibbereen
# Processing Record 41 of Set 7 | portland
# Processing Record 42 of Set 7 | fortuna
# Processing Record 43 of Set 7 | provideniya
# Processing Record 44 of Set 7 | krasnoselkup
# Processing Record 45 of Set 7 | juegang
# Processing Record 46 of Set 7 | nyurba
# Processing Record 47 of Set 7 | mayo
# Processing Record 48 of Set 7 | laguna
# Processing Record 49 of Set 7 | adrar
# Processing Record 50 of Set 7 | paita
# Processing Record 1 of Set 8 | lorengau
# Processing Record 2 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 8 | viedma
# Processing Record 5 of Set 8 | puerto colombia
# Processing Record 6 of Set 8 | broome
# Processing Record 7 of Set 8 | angol
# Processing Record 8 of Set 8 | joaima
# Processing Record 9 of Set 8 | yulara
# Processing Record 10 of Set 8 | maniitsoq
# Processing Record 11 of Set 8 | port shepstone
# Processing Record 12 of Set 8 | harrisonville
# Processing Record 13 of Set 8 | troitskoye
# Processing Record 14 of Set 8 | chute-aux-outardes
# Processing Record 15 of Set 8 | taikang
# Processing Record 16 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 17 of Set 8 | barguzin
# Processing Record 18 of Set 8 | mahenge
# Processing Record 19 of Set 8 | belmonte
# Processing Record 20 of Set 8 | yeppoon
# Processing Record 21 of Set 8 | fort nelson
# Processing Record 22 of Set 8 | goure
# Processing Record 23 of Set 8 | chapais
# Processing Record 24 of Set 8 | kuusamo
# Processing Record 25 of Set 8 | tsaratanana
# Processing Record 26 of Set 8 | riyadh
# Processing Record 27 of Set 8 | santa marinella
# Processing Record 28 of Set 8 | kenai
# Processing Record 29 of Set 8 | timmins
# Processing Record 30 of Set 8 | athmallik
# Processing Record 31 of Set 8 | teya
# Processing Record 32 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 8 | axim
# Processing Record 34 of Set 8 | tera
# Processing Record 35 of Set 8 | hofn
# Processing Record 36 of Set 8 | mahibadhoo
# Processing Record 37 of Set 8 | los llanos de aridane
# Processing Record 38 of Set 8 | kyra
# Processing Record 39 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 8 | ibiruba
# Processing Record 41 of Set 8 | lardos
# Processing Record 42 of Set 8 | yar-sale
# Processing Record 43 of Set 8 | sambava
# Processing Record 44 of Set 8 | coelho neto
# Processing Record 45 of Set 8 | grafton
# Processing Record 46 of Set 8 | omboue
# Processing Record 47 of Set 8 | camana
# Processing Record 48 of Set 8 | ust-nera
# Processing Record 49 of Set 8 | antofagasta
# Processing Record 50 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 1 of Set 9 | atar
# Processing Record 2 of Set 9 | pitimbu
# Processing Record 3 of Set 9 | general roca
# Processing Record 4 of Set 9 | bambanglipuro
# Processing Record 5 of Set 9 | paso de carrasco
# Processing Record 6 of Set 9 | cap malheureux
# Processing Record 7 of Set 9 | nhulunbuy
# Processing Record 8 of Set 9 | sangar
# Processing Record 9 of Set 9 | muros
# Processing Record 10 of Set 9 | bima
# Processing Record 11 of Set 9 | grindavik
# Processing Record 12 of Set 9 | naryan-mar
# Processing Record 13 of Set 9 | san jose
# Processing Record 14 of Set 9 | hope
# Processing Record 15 of Set 9 | talara
# Processing Record 16 of Set 9 | vestmannaeyjar
# Processing Record 17 of Set 9 | elko
# Processing Record 18 of Set 9 | lere
# Processing Record 19 of Set 9 | capreol
# Processing Record 20 of Set 9 | vila franca do campo
# Processing Record 21 of Set 9 | takestan
# Processing Record 22 of Set 9 | bagn
# Processing Record 23 of Set 9 | sumbe
# Processing Record 24 of Set 9 | biu
# Processing Record 25 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 9 | dzilam gonzalez
# Processing Record 27 of Set 9 | kailua
# Processing Record 28 of Set 9 | mwaro
# Processing Record 29 of Set 9 | kapit
# Processing Record 30 of Set 9 | vardo
# Processing Record 31 of Set 9 | beringovskiy
# Processing Record 32 of Set 9 | goderich
# Processing Record 33 of Set 9 | lindenberg
# Processing Record 34 of Set 9 | yerbogachen
# Processing Record 35 of Set 9 | pisco
# Processing Record 36 of Set 9 | makakilo city
# Processing Record 37 of Set 9 | dinard
# Processing Record 38 of Set 9 | corn island
# Processing Record 39 of Set 9 | valparaiso
# Processing Record 40 of Set 9 | itarema
# Processing Record 41 of Set 9 | erzin
# Processing Record 42 of Set 9 | sorong
# Processing Record 43 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 44 of Set 9 | kletskaya
# Processing Record 45 of Set 9 | dalhousie
# Processing Record 46 of Set 9 | sokoni
# Processing Record 47 of Set 9 | solsona
# Processing Record 48 of Set 9 | varkkallai
# Processing Record 49 of Set 9 | nang rong
# Processing Record 50 of Set 9 | uvalde
# Processing Record 1 of Set 10 | acarau
# Processing Record 2 of Set 10 | karratha
# Processing Record 3 of Set 10 | asfi
# Processing Record 4 of Set 10 | heidelberg
# Processing Record 5 of Set 10 | zhigansk
# Processing Record 6 of Set 10 | pontes e lacerda
# Processing Record 7 of Set 10 | grass valley
# Processing Record 8 of Set 10 | mandurah
# Processing Record 9 of Set 10 | islahiye
# Processing Record 10 of Set 10 | kontagora
# Processing Record 11 of Set 10 | burica
# City not found. Skipping...
# Processing Record 12 of Set 10 | pyaozerskiy
# Processing Record 13 of Set 10 | minab
# Processing Record 14 of Set 10 | burhanpur
# Processing Record 15 of Set 10 | champerico
# Processing Record 16 of Set 10 | hay river
# Processing Record 17 of Set 10 | matay
# Processing Record 18 of Set 10 | nianzishan
# Processing Record 19 of Set 10 | petrozavodsk
# Processing Record 20 of Set 10 | mangan
# Processing Record 21 of Set 10 | genhe
# Processing Record 22 of Set 10 | bijie
# Processing Record 23 of Set 10 | lukaya
# Processing Record 24 of Set 10 | imbituba
# Processing Record 25 of Set 10 | ahuimanu
# Processing Record 26 of Set 10 | russell
# Processing Record 27 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 28 of Set 10 | selishche
# Processing Record 29 of Set 10 | soke
# Processing Record 30 of Set 10 | saint anthony
# Processing Record 31 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 32 of Set 10 | pedro ii
# Processing Record 33 of Set 10 | taywarah
# Processing Record 34 of Set 10 | shakhunya
# Processing Record 35 of Set 10 | weligama
# Processing Record 36 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 10 | sabang
# Processing Record 38 of Set 10 | roald
# Processing Record 39 of Set 10 | ovalle
# Processing Record 40 of Set 10 | gobabis
# Processing Record 41 of Set 10 | pochutla
# Processing Record 42 of Set 10 | pueblo bello
# Processing Record 43 of Set 10 | kyabe
# Processing Record 44 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 45 of Set 10 | gillette
# Processing Record 46 of Set 10 | rio grande
# Processing Record 47 of Set 10 | khatanga
# Processing Record 48 of Set 10 | severodvinsk
# Processing Record 49 of Set 10 | bermejo
# Processing Record 50 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 11 | balykshi
# Processing Record 2 of Set 11 | eyl
# Processing Record 3 of Set 11 | sakakah
# Processing Record 4 of Set 11 | puerto quijarro
# Processing Record 5 of Set 11 | lavrentiya
# Processing Record 6 of Set 11 | pevek
# Processing Record 7 of Set 11 | mossendjo
# Processing Record 8 of Set 11 | drayton valley
# Processing Record 9 of Set 11 | yarmouth
# Processing Record 10 of Set 11 | stabat
# Processing Record 11 of Set 11 | san policarpo
# Processing Record 12 of Set 11 | prado
# Processing Record 13 of Set 11 | kitakata
# Processing Record 14 of Set 11 | porto novo
# Processing Record 15 of Set 11 | nizwa
# Processing Record 16 of Set 11 | waingapu
# Processing Record 17 of Set 11 | kidodi
# Processing Record 18 of Set 11 | conakry
# Processing Record 19 of Set 11 | poum
# Processing Record 20 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 11 | liku
# Processing Record 22 of Set 11 | serta
# Processing Record 23 of Set 11 | hambantota
# Processing Record 24 of Set 11 | tautira
# Processing Record 25 of Set 11 | firminy
# Processing Record 26 of Set 11 | camapua
# Processing Record 27 of Set 11 | katete
# Processing Record 28 of Set 11 | port hedland
# Processing Record 29 of Set 11 | diu
# Processing Record 30 of Set 11 | inongo
# Processing Record 31 of Set 11 | shingu
# Processing Record 32 of Set 11 | port-cartier
# Processing Record 33 of Set 11 | maragogi
# Processing Record 34 of Set 11 | batemans bay
# Processing Record 35 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 11 | lazaro cardenas
# Processing Record 37 of Set 11 | mafeteng
# Processing Record 38 of Set 11 | kardla
# Processing Record 39 of Set 11 | vao
# Processing Record 40 of Set 11 | san jose de guanipa
# Processing Record 41 of Set 11 | ushtobe
# Processing Record 42 of Set 11 | takoradi
# Processing Record 43 of Set 11 | samarai
# Processing Record 44 of Set 11 | yumbo
# Processing Record 45 of Set 11 | atlanta
# Processing Record 46 of Set 11 | camaguey
# Processing Record 47 of Set 11 | vila velha
# Processing Record 48 of Set 11 | jawar
# Processing Record 49 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 11 | hualmay
# Processing Record 1 of Set 12 | lenger
# Processing Record 2 of Set 12 | mosquera
# Processing Record 3 of Set 12 | warrington
# Processing Record 4 of Set 12 | mnogovershinnyy
# Processing Record 5 of Set 12 | usogorsk
# Processing Record 6 of Set 12 | port augusta
# Processing Record 7 of Set 12 | cockburn town
# Processing Record 8 of Set 12 | tawang
# Processing Record 9 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 10 of Set 12 | tres arroyos
# Processing Record 11 of Set 12 | shagonar
# Processing Record 12 of Set 12 | bunia
# Processing Record 13 of Set 12 | vereeniging
# Processing Record 14 of Set 12 | ascension
# Processing Record 15 of Set 12 | el tigre
# Processing Record 16 of Set 12 | ballina
# Processing Record 17 of Set 12 | popondetta
# Processing Record 18 of Set 12 | berlevag
# Processing Record 19 of Set 12 | andenes
# Processing Record 20 of Set 12 | sokol
# Processing Record 21 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 23 of Set 12 | vanimo
# Processing Record 24 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 12 | evensk
# Processing Record 26 of Set 12 | kathu
# Processing Record 27 of Set 12 | ndele
# Processing Record 28 of Set 12 | sao jose da coroa grande
# Processing Record 29 of Set 12 | agdam
# Processing Record 30 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 31 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 12 | haines junction
# Processing Record 33 of Set 12 | snyder
# Processing Record 34 of Set 12 | aasiaat
# Processing Record 35 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 12 | eden
# Processing Record 37 of Set 12 | hibbing
# Processing Record 38 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 12 | banjar
# Processing Record 40 of Set 12 | manggar
# Processing Record 41 of Set 12 | kodino
# Processing Record 42 of Set 12 | malindi
# Processing Record 43 of Set 12 | gazanjyk
# Processing Record 44 of Set 12 | luanda
# Processing Record 45 of Set 12 | bayir
# Processing Record 46 of Set 12 | nichinan
# Processing Record 47 of Set 12 | chokwe
# Processing Record 48 of Set 12 | port lincoln
# Processing Record 49 of Set 12 | chitrakonda
# Processing Record 50 of Set 12 | fergus falls
# Processing Record 1 of Set 13 | inhambane
# Processing Record 2 of Set 13 | cap-aux-meules
# Processing Record 3 of Set 13 | donghai
# Processing Record 4 of Set 13 | ahipara
# Processing Record 5 of Set 13 | lasa
# Processing Record 6 of Set 13 | rochegda
# Processing Record 7 of Set 13 | weyburn
# Processing Record 8 of Set 13 | antalaha
# Processing Record 9 of Set 13 | irbil
# Processing Record 10 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 13 | ambon
# Processing Record 12 of Set 13 | gravelbourg
# Processing Record 13 of Set 13 | turukhansk
# Processing Record 14 of Set 13 | svetlogorsk
# Processing Record 15 of Set 13 | hohhot
# Processing Record 16 of Set 13 | estevan
# Processing Record 17 of Set 13 | port-gentil
# Processing Record 18 of Set 13 | vastervik
# City not found. Skipping...
# Processing Record 19 of Set 13 | north battleford
# Processing Record 20 of Set 13 | volzhskiy
# Processing Record 21 of Set 13 | meiktila
# Processing Record 22 of Set 13 | verkhozim
# Processing Record 23 of Set 13 | bani
# Processing Record 24 of Set 13 | clevelandia
# Processing Record 25 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 13 | digha
# Processing Record 27 of Set 13 | gornopravdinsk
# Processing Record 28 of Set 13 | pahrump
# Processing Record 29 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 30 of Set 13 | bachaquero
# Processing Record 31 of Set 13 | santa fe
# Processing Record 32 of Set 13 | huilong
# Processing Record 33 of Set 13 | pitkyaranta
# Processing Record 34 of Set 13 | suntar
# Processing Record 35 of Set 13 | tatarsk
# Processing Record 36 of Set 13 | xining
# Processing Record 37 of Set 13 | egvekinot
# Processing Record 38 of Set 13 | yinchuan
# Processing Record 39 of Set 13 | ningan
# City not found. Skipping...
# Processing Record 40 of Set 13 | chillicothe
# Processing Record 41 of Set 13 | sao miguel do araguaia
# Processing Record 42 of Set 13 | veraval
# Processing Record 43 of Set 13 | nabire
# Processing Record 44 of Set 13 | jutai
# Processing Record 45 of Set 13 | moctezuma
# Processing Record 46 of Set 13 | kjollefjord
# Processing Record 47 of Set 13 | mazagao
# Processing Record 48 of Set 13 | kungurtug
# Processing Record 49 of Set 13 | bathsheba
# Processing Record 50 of Set 13 | san quintin
# Processing Record 1 of Set 14 | tarbes
# Processing Record 2 of Set 14 | ulaangom
# Processing Record 3 of Set 14 | basco
# Processing Record 4 of Set 14 | silyanah
# City not found. Skipping...
# Processing Record 5 of Set 14 | bariadi
# Processing Record 6 of Set 14 | berdigestyakh
# Processing Record 7 of Set 14 | santander
# Processing Record 8 of Set 14 | codajas
# Processing Record 9 of Set 14 | mezen
# Processing Record 10 of Set 14 | sa kaeo
# Processing Record 11 of Set 14 | aketi
# Processing Record 12 of Set 14 | dickinson
# Processing Record 13 of Set 14 | olafsvik
# Processing Record 14 of Set 14 | kouango
# Processing Record 15 of Set 14 | camacha
# Processing Record 16 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 17 of Set 14 | tuy hoa
# Processing Record 18 of Set 14 | derzhavinsk
# Processing Record 19 of Set 14 | trelew
# Processing Record 20 of Set 14 | lakes entrance
# Processing Record 21 of Set 14 | ellensburg
# Processing Record 22 of Set 14 | maues
# Processing Record 23 of Set 14 | bumba
# Processing Record 24 of Set 14 | belo jardim
# Processing Record 25 of Set 14 | caucasia
# Processing Record 26 of Set 14 | thunder bay
# Processing Record 27 of Set 14 | kavieng
# Processing Record 28 of Set 14 | ammon
# Processing Record 29 of Set 14 | sarai
# Processing Record 30 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 31 of Set 14 | ukiah
# Processing Record 32 of Set 14 | solnechnyy
# Processing Record 33 of Set 14 | praia da vitoria
# Processing Record 34 of Set 14 | villanueva
# Processing Record 35 of Set 14 | jacareacanga
# Processing Record 36 of Set 14 | havoysund
# Processing Record 37 of Set 14 | lososina
# Processing Record 38 of Set 14 | vaitape
# Processing Record 39 of Set 14 | necochea
# Processing Record 40 of Set 14 | bafq
# Processing Record 41 of Set 14 | esna
# Processing Record 42 of Set 14 | malibu
# Processing Record 43 of Set 14 | bar harbor
# Processing Record 44 of Set 14 | lazarev
# Processing Record 45 of Set 14 | tongliao
# Processing Record 46 of Set 14 | wawa
# Processing Record 47 of Set 14 | port blair
# Processing Record 48 of Set 14 | tessalit
# Processing Record 49 of Set 14 | turka
# Processing Record 50 of Set 14 | gazojak
# Processing Record 1 of Set 15 | san lazaro
# Processing Record 2 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 3 of Set 15 | tupik
# Processing Record 4 of Set 15 | mana
# Processing Record 5 of Set 15 | xuanwu
# Processing Record 6 of Set 15 | staryy nadym
# Processing Record 7 of Set 15 | akyab
# Processing Record 8 of Set 15 | avera
# Processing Record 9 of Set 15 | guerrero negro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 650

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Atuona      PF  -9.8000 -139.0333     77.22        68
# 1           Constitucion      CL -35.3333  -72.4167     50.49        79
# 2                 Hobart      AU -42.8794  147.3294     43.27       100
# 3                Ushuaia      AR -54.8000  -68.3000     33.35        94
# 4             Codrington      AU -38.2667  141.9667     46.27        93
# 5                Rikitea      PF -23.1203 -134.9692     73.15        70
# 6             Kaitangata      NZ -46.2817  169.8464     37.96        74
# 7                 Bethel      US  41.3712  -73.4140     88.81        53
# 8                Isangel      VU -19.5500  169.2667     73.06        57
# 9  San Nicolas Guadalupe      MX  19.6125 -100.0333     60.31        66
#
#    Cloudiness  Wind Speed Current Description
# 0          33       25.48    scattered clouds
# 1           0        5.66           clear sky
# 2          75        0.00       broken clouds
# 3          92        2.59     overcast clouds
# 4         100        3.06     overcast clouds
# 5          77       20.94       broken clouds
# 6          13        6.33          few clouds
# 7         100        1.52     overcast clouds
# 8          10       15.57           clear sky
# 9         100        1.34     overcast clouds

# %%
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
